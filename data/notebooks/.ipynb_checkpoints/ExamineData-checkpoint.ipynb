# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## Combining Data

# %%
COMBINE_DATASETS = False
if COMBINE_DATASETS:
    old_names = ['29_06','30_06','01_07','02_07','03_07','04_07','05_07','06_07'] + [f'retry_run{n}' for n in range(1,7)]
    old_locations = [f"../experiments/collected_data_{fname}.csv" for fname in old_names]
    new_locations = ["../experiments/collected_data_berlinersplit.csv", "../experiments/collected_data_baserulesafter.csv"]
    old_raw = pd.concat([pd.read_csv(location) for location in old_locations])
    new_raw = pd.concat([pd.read_csv(location) for location in new_locations])
    per_run_old = old_raw.groupby(['seed','algorithm']).first()
    per_run_new = new_raw.groupby(['seed','algorithm']).first()
    per_run_upd = per_run_old.copy()
    per_run_upd.loc[per_run_new.index] = per_run_new
    upd_raw = per_run_upd.reset_index()[list(old_raw.columns)]
    upd_raw.to_csv("../experiments/combined_data.zip", index=False, compression={'method':'zip', 'archive_name':"combined_data.csv"})
    del old_names, old_locations, new_locations, old_raw, new_raw, per_run_old, per_run_new, per_run_upd, upd_raw

# %% [markdown]
# ## Loading Data

# %%
# main_raw = pd.read_csv("../experiments/combined_data.zip")
# main_raw = pd.read_csv("../experiments/collected_data_alt_compare.csv")
main_raw = pd.read_csv("../experiments/combined_data_153.zip")

# %%
main = main_raw.copy()
main.PS = main_raw.PS == "yes"
main.intractable = main_raw.intractable == "yes"
algos = main_raw.algorithm.unique(); algos.sort()
for algo in algos:
    main[algo] = main_raw.algorithm == algo

# %%
# solved by all:
gby = main[~main.intractable].groupby('seed')
counts = gby.algorithm.count()
seeds_all = main.seed.isin(counts[counts==len(algos)].index)
main_all = main[seeds_all].drop(columns=list(algos)+['intractable'])
del gby, counts, seeds_all

# %%
# solved by none:
gby = main[main.intractable].groupby('seed')
counts = gby.algorithm.count()
seeds_none = main.seed.isin(counts[counts==len(algos)].index)
main_none = main[seeds_none].drop(columns=list(algos)+['intractable'])
main_none['distance'] = main_none.sepValue / main_none.range
del gby, counts, seeds_none

# %% [markdown]
# ## Validation:

# %%
per_tree = main_raw[main_raw.intractable == "no"].groupby('seed')
_num_solutions = per_tree.solution.apply(lambda x : len(x.unique()))
_num_sepvals = per_tree.sepValue.apply(lambda x : len(x.unique()))
df0 = main.join(pd.DataFrame({"numsol": _num_solutions, "numsep": _num_sepvals}), on="seed").fillna(0)
print("if all goes well, the following printed frame is empty:")
display(df0[(df0.numsol > 1) & (df0.numsep > 1)])
del df0, _num_sepvals, _num_solutions, per_tree
# Out:
# if all goes well, the following printed frame is empty:
# Empty DataFrame
# Columns: [style, algorithm, growth, PS, num_alts, force_chance, seed, range, width, seconds, depth, evaluated, expanded, intractable, solution, depth1Pes, depth2Opt, sepValue, DB-AR-0.8, DB-AR-1.0, DB-AR-1.4, DB-AR-1.6, DB-AR-2.0, altern-DB, alternate, always-PB, berlin-2D, berlin-2R, berlin-3D, berlin-3R, berlin-AD, berlin-AR, prefer-DR, randomize, numsol, numsep]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# ## Compute number of problems solved by algorithm pair

# %%
gby = main[~main.intractable].groupby('seed')
pair_counts = {a: {b: (gby[a].any() & gby[b].any()).sum() for b in algos} for a in algos}
main_pairs = pd.DataFrame(pair_counts)
del gby, pair_counts

# %%
algos2 = list(algos)
algos2.sort(key=lambda x : main_pairs.loc[x,x])

# %% [markdown]
# The following figure shows the number of trees that were solved (`not intractable`) by any pair of algorithms. You can also read the total number of trees solved for a specific algorithm off the diagonal of this figure:

# %%
number_of_trees_solved_total = main[~main.intractable].groupby('seed').algorithm.count().size
sns.heatmap(main_pairs.loc[algos2, algos2] / number_of_trees_solved_total)
plt.title('Pairs of Algorithms: Number of Trees Solved in Common')
print(f"Overall, {100*number_of_trees_solved_total / main.seed.unique().size:.1f}% of trees are solved by any algorithm.")
print(f"The best algorithm could solve {100*main_pairs.max().max() / number_of_trees_solved_total:.2f}% of all solved trees")
# Out:
# Overall, 70.5% of trees are solved by any algorithm.
# The best algorithm could solve 94.86% of all solved trees

# %%
for style in main["style"].unique():
    temp = main[main["style"] == style]
    algo_select = [alg for alg in algos2 if "DB-Ar" in alg or ("berlin-" in alg and "Ar" in alg) or ("berlin-" in alg and "3r" in alg)]
    ys = [temp[temp.algorithm == alg].intractable.sum()for alg in algo_select]
    plt.plot(algo_select, ys)
    plt.xticks(rotation=45, ha='right')
    plt.title(f"Number of intractable for {style} trees")
    plt.show()

# %%
sns.heatmap(main.groupby(['width','num_alts']).intractable.sum().unstack(level=1), cmap="Reds", vmin=0)
plt.title("number of intractable trees per tree parameters");

# %%
sns.heatmap(main.groupby(['style','num_alts']).intractable.sum().unstack(level=1), cmap="Reds", vmin=0)
plt.title("number of intractable trees per tree parameters");

# %%
sns.heatmap(main.groupby(['width','range']).intractable.sum().unstack(level=1), cmap="Reds", vmin=0)
plt.title("number of intractable trees per tree parameters");

# %%
main_all.columns
# Out:
# Index(['style', 'algorithm', 'growth', 'PS', 'num_alts', 'force_chance',
#        'seed', 'range', 'width', 'seconds', 'depth', 'evaluated', 'expanded',
#        'solution', 'depth1Pes', 'depth2Opt', 'sepValue'],
#       dtype='object')

# %%
df = main[(main["style"]=="BaseRulesAfter") | (main["style"]=="BaseRulesBefore")]
sns.heatmap(df.groupby(['growth','width','num_alts']).intractable.sum().unstack(level=1), cmap="Reds", vmin=0)
plt.title("number of intractable trees per tree parameters");
del df

# %%
sns.barplot(main_all, x="num_alts", y="evaluated", hue="algorithm", hue_order=algos2, errorbar=None)
plt.title("Effort expended on problems solved by all")
plt.legend(bbox_to_anchor=(1.01, 1), loc="upper left")
plt.show()
sns.barplot(main_all, x="num_alts", y="seconds", hue="algorithm", hue_order=algos2, errorbar=None)
plt.title("Time spent on problems solved by all")
plt.legend(bbox_to_anchor=(1.01, 1), loc="upper left");

# %%
sns.barplot(main_all, x="width", y="evaluated", hue="algorithm", hue_order=algos2, errorbar=None)
plt.title("Effort expended on problems solved by all")
plt.legend(bbox_to_anchor=(1.01, 1), loc="upper left")
plt.show()
sns.barplot(main_all, x="width", y="seconds", hue="algorithm", hue_order=algos2, errorbar=None)
plt.title("Time spent on problems solved by all")
plt.legend(bbox_to_anchor=(1.01, 1), loc="upper left");

# %%
for style in main_none['style'].unique():
    sns.barplot(main_none[main_none["style"] == style], x="num_alts", y="distance", hue="algorithm", hue_order=algos2, errorbar=None)
    plt.title(f"Progress made on the most difficult problems - {style}")
    plt.legend(bbox_to_anchor=(1.01, 1), loc="upper left")
    plt.show()
    # sns.barplot(main_none[main_none["style"] == style], x="num_alts", y="seconds", hue="algorithm", hue_order=algos2, errorbar=None)
    # plt.title("Time spent on the most difficult problems")
    # plt.legend(bbox_to_anchor=(1.01, 1), loc="upper left");

# %% [markdown]
# ## Examine interesting patterns

# %%
def graph(df, name):
    xr = df.groupby(['range', 'width']).sepValue.mean(); xr = xr / xr.index.get_level_values(0)
    pd.DataFrame({'sepvals':xr}).reset_index().set_index('width').sepvals.plot(marker='.', linestyle='none',label="mean - trees with same range")
    xr.groupby('width').mean().plot(label="mean - all trees");
    plt.legend()
    plt.xlabel("nr. of available moves per turn")
    plt.ylabel("Proven pessimistic value at root")
    plt.title(f"Number of moves correlates with P2M advantage{name}");

# %%
for style in main_all['style'].unique():
    graph(main_all[main_all['style']==style], f" - {style}")
    plt.show()

# %%
algos2
# Out:
# ['always-PB',
#  'prefer-DR',
#  'altern-DB',
#  'randomize',
#  'alternate',
#  'berlin-AD',
#  'berlin-3D',
#  'berlin-2D',
#  'berlin-2R',
#  'berlin-AR',
#  'DB-AR-0.8',
#  'DB-AR-1.0',
#  'berlin-3R',
#  'DB-AR-1.4',
#  'DB-AR-1.6',
#  'DB-AR-2.0']

# %%
__ = slice(None)
algorithms = algos2[2:]#["alternate", "altern-DB", "berlin-AR", "DB-AR-2.0"]
metric = "expanded"

data = main_all.groupby(['seed','algorithm']).first().loc[(__,algorithms),:]
BF = main_all[main_all.algorithm == "always-PB"].groupby('seed').first()

data["ratio"] = None
data["treesize"] = None
for alg in algorithms:
    if alg == "always-PB": continue
    data.loc[(__,alg), "ratio"] = data.loc[(__,alg), metric] / BF.loc[:, metric]
    data.loc[(__,alg), "treesize"] = round((data.loc[(__,alg), metric] + BF.loc[:, metric] - data.loc[(__,alg), metric]) / 50) * 50
data = data.reset_index()
data.ratio = data.ratio.astype(float)
data.treesize = data.treesize.astype(int)

ax = sns.pointplot(data[(data.treesize <= 1500)], x="treesize", y="ratio", hue="algorithm", hue_order=algorithms)
plt.xticks([0,5,10,15,20,25,30])
ax.legend(bbox_to_anchor=(1.3, 1))
